# %% [markdown]
# # Figure 7 — Gradient Magnitude
# Reproduces Figure 7 of Huang et al. 2016.
#
# 1. Run **Mount & Copy** cell first.
# 2. Run one training cell per tab — Tab 3: stochastic, Tab 4: baseline.
#
# > Runtime → Change runtime type → **A100 GPU**

# %%
from google.colab import drive
drive.mount('/content/drive')

import shutil, os
ROOT = '/content/drive/MyDrive/stoch_depth'

for fname in ['model.py', 'data.py', 'train.py', 'evaluate.py']:
    shutil.copy(f'{ROOT}/code/{fname}', f'/content/{fname}')
    print(f'Copied {fname}')

# %%
# !nvidia-smi --query-gpu=name,memory.total --format=csv,noheader

# %% [markdown]
# ## Train — Stochastic Depth (Tab 3)

# %%
import os
ROOT = '/content/drive/MyDrive/stoch_depth'
CKPT = f'{ROOT}/fig7/stochastic/checkpoints/cifar10_pL0.5_modelinear_n18_last.pt'
RESUME = f'--resume {CKPT}' if os.path.exists(CKPT) else ''
OUT = f'{ROOT}/fig7/stochastic'

# !python /content/train.py \
    --dataset cifar10 --p_L 0.5 --survival_mode linear \
    --epochs 500 --log_grad \
    --data_root /content/data \
    --num_workers 2 \
    --out_dir $OUT \
    $RESUME

# %% [markdown]
# ## Train — Constant Depth Baseline (Tab 4)

# %%
import os
ROOT = '/content/drive/MyDrive/stoch_depth'
CKPT = f'{ROOT}/fig7/baseline/checkpoints/cifar10_pL1.0_modeconstant_n18_last.pt'
RESUME = f'--resume {CKPT}' if os.path.exists(CKPT) else ''
OUT = f'{ROOT}/fig7/baseline'

# !python /content/train.py \
    --dataset cifar10 --p_L 1.0 --survival_mode constant \
    --epochs 500 --log_grad \
    --data_root /content/data \
    --num_workers 2 \
    --out_dir $OUT \
    $RESUME
